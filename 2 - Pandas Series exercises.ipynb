# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# # Pandas Series exercises

# %%
# Import the numpy package under the name np
import numpy as np

# Import the pandas package under the name pd
import pandas as pd

# Print the pandas version and the configuration
print(pd.__version__)
# Out:
# 2.2.2

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Series creation

# %% [markdown]
# ### Create an empty pandas Series

# %%
a = pd.Series()

# %%
pd.Series()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X python list convert it to an Y pandas Series

# %%
X = ['A','B','C']
print(X, type(X))
Y = pd.Series(X)
print(Y, type(Y))
Y
# Out:
# ['A', 'B', 'C'] <class 'list'>
# 0    A
# 1    B
# 2    C
# dtype: object <class 'pandas.core.series.Series'>
# 0    A
# 1    B
# 2    C
# dtype: object

# %%
X = ['A','B','C']
print(X, type(X))

Y = pd.Series(X)
print(Y, type(Y)) # different type

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, name it 'My letters'

# %%
X = pd.Series(['A','B','C'])
X.name = 'My letters'
X
# Out:
# 0    A
# 1    B
# 2    C
# Name: My letters, dtype: object

# %%
X = pd.Series(['A','B','C'])

X.name = 'My letters'
X
# Out:
# 0    A
# 1    B
# 2    C
# Name: My letters, dtype: object

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, show its values

# %%
X = pd.Series(['A','B','C'])
X.values
# Out:
# array(['A', 'B', 'C'], dtype=object)

# %%
X = pd.Series(['A','B','C'])

X.values
# Out:
# array(['A', 'B', 'C'], dtype=object)

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Series indexation

# %% [markdown]
# ### Assign index names to the given X pandas Series

# %%
X = pd.Series(['A','B','C'])
X.index = ["Almaty","Barys","Canada"]
X
# Out:
# Almaty    A
# Barys     B
# Canada    C
# dtype: object

# %%
X = pd.Series(['A','B','C'])
index_names = ['first', 'second', 'third']

X.index = index_names
X

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, show its first element

# %%
X = pd.Series((['A','B','C']), index = ['first', 'second', 'third'])
X.iloc(0)
X['first']
# Out:
# 'A'

# %%
X = pd.Series(['A','B','C'], index=['first', 'second', 'third'])

#X[0] # by position
#X.iloc[0] # by position
X['first'] # by index
# Out:
# 'A'

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, show its last element

# %%
X = pd.Series(['A','B','C'], index=['first', 'second', 'third'])
X[-1]
X.iloc[-1]
X['third']
X
# Out:
# /tmp/ipykernel_18438/3758905910.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   X[-1]
# first     A
# second    B
# third     C
# dtype: object

# %%
X = pd.Series(['A','B','C'], index=['first', 'second', 'third'])

#X[-1] # by position
#X.iloc[-1] # by position
X['third'] # by index

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, show all middle elements

# %%
X = pd.Series(['A','B','C','D','E'], index=['first', 'second', 'third', 'fourth', 'fives'])
X[1:-1]
# Out:
# second    B
# third     C
# fourth    D
# dtype: object

# %%
X = pd.Series(['A','B','C','D','E'],
              index=['first','second','third','forth','fifth'])

#X[['second', 'third', 'forth']]
#X.iloc[1:-1] # by position
X[1:-1] # by position

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, show the elements in reverse position

# %%
X = pd.Series(['A','B','C','D','E'], index=['first', 'second', 'third', 'fourth', 'fives'])
X[::-1]
# Out:
# fives     E
# fourth    D
# third     C
# second    B
# first     A
# dtype: object

# %%
X = pd.Series(['A','B','C','D','E'],
              index=['first','second','third','forth','fifth'])

#X.iloc[::-1]
X[::-1]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, show the first and last elements

# %%
X = pd.Series(['A','B','C','D','E'], index=['first','second','third','forth','fifth'])
X[['first','fifth']]
# Out:
# first    A
# fifth    E
# dtype: object

# %%
X = pd.Series(['A','B','C','D','E'],
              index=['first','second','third','forth','fifth'])

#X[['first', 'fifth']]
#X.iloc[[0, -1]]
X[[0, -1]]
# Out:
# /tmp/ipykernel_18438/1500303121.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   X[[0, -1]]
# first    A
# fifth    E
# dtype: object

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Series manipulation

# %% [markdown]
# ### Convert the given integer pandas Series to float

# %%
X = pd.Series([1,2,3,4,5],
              index=['first','second','third','forth','fifth'])
pd.Series(X, dtype = np.float64)
# Out:
# first     1.0
# second    2.0
# third     3.0
# forth     4.0
# fifth     5.0
# dtype: float64

# %%
X = pd.Series([1,2,3,4,5],
              index=['first','second','third','forth','fifth'])

pd.Series(X, dtype=np.float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_18438/3515785985.py in <cell line: 0>()
#       2               index=['first','second','third','forth','fifth'])
#       3
# ----> 4 pd.Series(X, dtype=np.float)
#
# /usr/local/lib/python3.12/dist-packages/numpy/__init__.py in __getattr__(attr)
#     392
#     393         if attr in __former_attrs__:
# --> 394             raise AttributeError(__former_attrs__[attr])
#     395
#     396         if attr in __expired_attributes__:
#
# AttributeError: module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Reverse the given pandas Series (first element becomes last)

# %%
X = pd.Series([1,2,3,4,5],
              index=['first','second','third','forth','fifth'])
X = X[::-1]

# %%
X = pd.Series([1,2,3,4,5],
              index=['first','second','third','forth','fifth'])

X[::-1]
# Out:
# fifth     5
# forth     4
# third     3
# second    2
# first     1
# dtype: int64

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Order (sort) the given pandas Series

# %%
X = np.sort(pd.Series([4,2,3,7,8],
              index=['first','second','third','forth','fifth']))
X
# Out:
# array([2, 3, 4, 7, 8])

# %%
X = pd.Series([4,2,5,1,3],
              index=['forth','second','fifth','first','third'])

X = X.sort_values()
X
# Out:
# first     1
# second    2
# third     3
# forth     4
# fifth     5
# dtype: int64

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, set the fifth element equal to 10

# %%
X = pd.Series([4,2,5,1,3],index=['forth','second','fifth','first','third'])
X[4] = 10
X
# Out:
# /tmp/ipykernel_18438/2747364382.py:2: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   X[4] = 10
# forth      4
# second     2
# fifth      5
# first      1
# third     10
# dtype: int64

# %%
X = pd.Series([1,2,3,4,5],
              index=['A','B','C','D','E'])

X[4] = 10
X

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, change all the middle elements to 0

# %%
X = pd.Series([1,2,3,4,5], index = ['A','B','C','D','E'])
X[1:-1] = 0
X
# Out:
# A    1
# B    0
# C    0
# D    0
# E    5
# dtype: int64

# %%
X = pd.Series([1,2,3,4,5],
              index=['A','B','C','D','E'])

X[1:-1] = 0
X

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, add 5 to every element

# %%
X = pd.Series([1,2,3,4,5], index = ['A','B','C','D','E'])
X = X + 5
X
# Out:
# A     6
# B     7
# C     8
# D     9
# E    10
# dtype: int64

# %%
X = pd.Series([1,2,3,4,5])

X + 5

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Series boolean arrays (also called masks)

# %% [markdown]
# ### Given the X pandas Series, make a mask showing negative elements

# %%
X = pd.Series([-1,2,0,-4,5,6,0,0,-9,10])
mask = X <= 0
X[mask]
# Out:
# 0   -1
# 2    0
# 3   -4
# 6    0
# 7    0
# 8   -9
# dtype: int64

# %%
X = pd.Series([-1,2,0,-4,5,6,0,0,-9,10])

mask = X <= 0
mask

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, get the negative elements

# %%
X = pd.Series([-1,2,0,-4,5,6,0,0,-9,10])
mask = X <= 0
X[mask]
# Out:
# 0   -1
# 2    0
# 3   -4
# 6    0
# 7    0
# 8   -9
# dtype: int64

# %%
X = pd.Series([-1,2,0,-4,5,6,0,0,-9,10])

mask = X <= 0
X[mask]
# Out:
# 0   -1
# 2    0
# 3   -4
# 6    0
# 7    0
# 8   -9
# dtype: int64

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, get numbers higher than 5

# %%
X = pd.Series([-1,2,0,-4,5,6,0,0,-9,10])
mask = X >= 0
X[mask]
# Out:
# 1     2
# 2     0
# 4     5
# 5     6
# 6     0
# 7     0
# 9    10
# dtype: int64

# %%
X = pd.Series([-1,2,0,-4,5,6,0,0,-9,10])

mask = X > 5
X[mask]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, get numbers higher than the elements mean

# %%
X = pd.Series([-1,2,0,-4,5,6,0,0,-9,10])
mask = X > X.mean()
X[mask]
# Out:
# 1     2
# 4     5
# 5     6
# 9    10
# dtype: int64

# %%
X = pd.Series([-1,2,0,-4,5,6,0,0,-9,10])

mask = X > X.mean()
X[mask]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, get numbers equal to 2 or 10

# %%
X = pd.Series([-1,2,0,-4,5,6,0,0,-9,10])

mask = (X == 2) | (X == 10)
X[mask]
# Out:
# 1     2
# 9    10
# dtype: int64

# %%
X = pd.Series([-1,2,0,-4,5,6,0,0,-9,10])

mask = (X == 2) | (X == 10)
X[mask]
# Out:
# 1     2
# 9    10
# dtype: int64

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Logic functions

# %% [markdown]
# [Текст ссылки](https://)### Given the X pandas Series, return True if none of its elements is zero

# %%
X = pd.Series([-1,2,0,-4,5,6,0,0,-9,10])
mask = X != 0
mask.all()
# Out:
# np.False_

# %%
X = pd.Series([-1,2,0,-4,5,6,0,0,-9,10])

X.all()
# Out:
# np.False_

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, return True if any of its elements is zero

# %%
X = pd.Series([-1,2,0,-4,5,6,0,0,-9,10])
X.any()
# Out:
# np.True_

# %%
X = pd.Series([-1,2,0,-4,5,6,0,0,-9,10])

X.any()
# Out:
# np.True_

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Summary statistics

# %% [markdown]
# ### Given the X pandas Series, show the sum of its elements

# %%
X = pd.Series([3,5,6,7,2,3,4,5,5])
X[1:4].sum()
# Out:
# np.int64(18)

# %%
X = pd.Series([3,5,6,7,2,3,4,9,4])

#np.sum(X)
X.sum()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, show the mean value of its elements

# %%
X = pd.Series([3,5,6,7,2,3,4,5,5])
X.mean()
# Out:
# np.float64(4.444444444444445)

# %%
X = pd.Series([1,2,0,4,5,6,0,0,9,10])

#np.mean(X)
X.mean()
# Out:
# np.float64(3.7)

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the X pandas Series, show the max value of its elements

# %%
X = pd.Series([1,2,0,4,5,6,0,0,9,10])
X.max()
# Out:
# 10

# %%
X = pd.Series([1,2,0,4,5,6,0,0,9,10])

#np.max(X)
X.max()

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
